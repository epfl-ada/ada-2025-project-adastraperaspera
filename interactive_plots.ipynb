# %% [markdown]
# # Interactive html plots generators

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
from src.scripts.visualization.interactive_plots import make_wt_tg_age_grid_scatter_from_csv

# %%
files = {
    "tg17": "src/data/Xenium_V1_FFPE_TgCRND8_17_9_months/normalized_counts_with_global_clusters_tg-17_with_plaque_data.csv",
    "tg5":  "src/data/Xenium_V1_FFPE_TgCRND8_5_7_months/normalized_counts_with_global_clusters_tg-5.csv",
    "tg2":  "src/data/Xenium_V1_FFPE_TgCRND8_2_5_months/normalized_counts_with_global_clusters_tg-2.csv",
    "wt13": "src/data/Xenium_V1_FFPE_wildtype_13_4_months/normalized_counts_with_global_clusters_wt-13.csv",
    "wt5":  "src/data/Xenium_V1_FFPE_wildtype_5_7_months/normalized_counts_with_global_clusters_wt-5.csv",
    "wt2":  "src/data/Xenium_V1_FFPE_wildtype_2_5_months/normalized_counts_with_global_clusters_wt-2.csv",
}

# %%
age_map = {
    "2.5": ("wt2", "tg2"),
    "5.7": ("wt5", "tg5"),
    "13+": ("wt13", "tg17"),
}

fig = make_wt_tg_age_grid_scatter_from_csv(
    csv_paths=files,
    age_map=age_map,
    title="Spatial cell maps — WT vs TG",
    filename="wt_tg_age_grid.html",
    max_points=200_000,
    reverse_y=True,     # likely needed for tissue-like coords
    swap_xy=False,      # set True if it’s truly swapped
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       1 age_map = {
#       2     "2.5": ("wt2", "tg2"),
#       3     "5.7": ("wt5", "tg5"),
#       4     "13+": ("wt13", "tg17"),
#       5 }
# ----> 7 fig = make_wt_tg_age_grid_scatter_from_csv(
#       8     csv_paths=files,
#       9     age_map=age_map,
#      10     title="Spatial cell maps — WT vs TG",
#      11     filename="wt_tg_age_grid.html",
#      12     max_points=200_000,
#      13     reverse_y=True,     # likely needed for tissue-like coords
#      14     swap_xy=False,      # set True if it’s truly swapped
#      15 )
#      16 fig.show()
#
# File c:\Users\rosam\OneDrive\Documents\Cours\ADA\project\ada-2025-project-adastraperaspera\src\scripts\visualization\interactive_plots.py:925, in make_wt_tg_age_grid_scatter_from_csv(csv_paths, age_map, title, filename, out_dir, max_points, x_candidates, y_candidates, reverse_y, swap_xy, marker_size, marker_opacity, color_col, row_label_wt, row_label_tg, row_label_font_size)
#     922     raise ValueError("age_map should contain exactly 3 ages for a 2×3 grid.")
#     924 # ---- create subplot grid ----
# --> 925 fig = make_subplots(
#     926     rows=2,
#     927     cols=3,
#     928     column_titles=[f"{a} months" if a.replace('.', '', 1).isdigit() else f"{a} months" for a in age_labels],
#     929     horizontal_spacing=0.02,
#     930     vertical_spacing=0.06,
#     931 )
#     933 # Track global ranges so all panels match (no jumping/unequal zoom)
#     934 xmins, xmaxs, ymins, ymaxs = [], [], [], []
#
# NameError: name 'make_subplots' is not defined
